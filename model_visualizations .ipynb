# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
cvec = pd.read_csv('./csv_model_statistics/cvec_model_statistics_with_boost.csv')
tfidif = pd.read_csv('./csv_model_statistics/tfidif_model_statistics_with_boost.csv')

# %%
cvec['Model'] = cvec['Model'].astype(str) + '_cvec'
tfidif['Model'] = tfidif['Model'].astype(str) + '_tfidif'

# %%
cvec
# Out:
#                                Model  Accuracy  Misclassification Rate  \
# 0             linear_regression_cvec  0.835206                0.164794
# 1   linear_regression_with_grid_cvec  0.941323                0.058677
# 2            k_nearest_neighbor_cvec  0.303371                0.696629
# 3  k_nearest_neighbor_with_grid_cvec  0.303371                0.696629
# 4                random_forrest_cvec  0.947566                0.052434
# 5      random_forrest_with_grid_cvec  0.926342                0.073658
# 6                   extra_trees_cvec  0.950062                0.049938
# 7          extra_trees_wit_grid_cvec  0.950062                0.049938
# 8            voting_class_boost_cvec  0.922597                0.077403
#
#    Sensitivity  Specificity  Precision
# 0     0.993548     0.616071   0.781726
# 1     0.990975     0.829960   0.928934
# 2     0.971429     0.272846   0.057530
# 3     0.971429     0.272846   0.057530
# 4     0.987567     0.852941   0.940778
# ...

# %%
tfidif
# Out:
#                                  Model  Accuracy  Misclassification Rate  \
# 0             linear_regression_tfidif  0.918851                0.081149
# 1   linear_regression_with_grid_tfidif  0.933833                0.066167
# 2            k_nearest_neighbor_tfidif  0.277154                0.722846
# 3  k_nearest_neighbor_with_grid_tfidif  0.277154                0.722846
# 4                random_forrest_tfidif  0.950062                0.049938
# 5      random_forrest_with_grid_tfidif  0.942572                0.057428
# 6                   extra_trees_tfidif  0.963795                0.036205
# 7          extra_trees_wit_grid_tfidif  0.963795                0.036205
# 8            voting_class_boost_tfidif  0.946317                0.053683
#
#    Sensitivity  Specificity  Precision
# 0     0.979927     0.786561   0.908629
# 1     0.954392     0.875598   0.956007
# 2     1.000000     0.266160   0.020305
# 3     1.000000     0.266160   0.020305
# ...

# %%
combined = cvec.append(tfidif).sort_values('Model').reset_index(drop = True)

# %%
mis = combined[['Model','Misclassification Rate']]

# %%
com = combined.drop('Misclassification Rate', axis =1)

# %%
tp = com.set_index('Model').T

# %%
tp
# Out:
# Model        extra_trees_cvec  extra_trees_tfidif  extra_trees_wit_grid_cvec  \
# Accuracy             0.950062            0.963795                   0.950062
# Sensitivity          0.987611            0.987847                   0.987611
# Specificity          0.860169            0.902222                   0.860169
# Precision            0.944162            0.962775                   0.944162
#
# Model        extra_trees_wit_grid_tfidif  k_nearest_neighbor_cvec  \
# Accuracy                        0.963795                 0.303371
# Sensitivity                     0.987847                 0.971429
# Specificity                     0.902222                 0.272846
# Precision                       0.962775                 0.057530
#
# Model        k_nearest_neighbor_tfidif  k_nearest_neighbor_with_grid_cvec  \
# Accuracy                      0.277154                           0.303371
# Sensitivity                   1.000000                           0.971429
# ...

# %%
tp.columns
# Out:
# Index(['extra_trees_cvec', 'extra_trees_tfidif', 'extra_trees_wit_grid_cvec',
#        'extra_trees_wit_grid_tfidif', 'k_nearest_neighbor_cvec',
#        'k_nearest_neighbor_tfidif', 'k_nearest_neighbor_with_grid_cvec',
#        'k_nearest_neighbor_with_grid_tfidif', 'linear_regression_cvec',
#        'linear_regression_tfidif', 'linear_regression_with_grid_cvec',
#        'linear_regression_with_grid_tfidif', 'random_forrest_cvec',
#        'random_forrest_tfidif', 'random_forrest_with_grid_cvec',
#        'random_forrest_with_grid_tfidif', 'voting_class_boost_cvec',
#        'voting_class_boost_tfidif'],
#       dtype='object', name='Model')

# %%
plt.figure(figsize = (10,10))
sns.set()
sns.scatterplot(x="extra_trees_cvec", y="extra_trees_tfidif", data=tp, hue = tp.index, s = 200);

# %%
plt.figure(figsize = (10,10))
sns.set()
sns.scatterplot(x="extra_trees_wit_grid_cvec", y="extra_trees_wit_grid_tfidif", data=tp, hue = tp.index, s = 200);

# %%
plt.figure(figsize = (10,10))

sns.set()
sns.scatterplot(x="k_nearest_neighbor_cvec", y="k_nearest_neighbor_tfidif", data=tp, hue = tp.index, s = 200);

# %%
plt.figure(figsize = (10,10))
sns.set()
sns.scatterplot(x="k_nearest_neighbor_with_grid_cvec", y="k_nearest_neighbor_with_grid_tfidif", data=tp, hue = tp.index, s = 200);

# %%
plt.figure(figsize = (10,10))
sns.set()
sns.scatterplot(x="linear_regression_cvec", y="linear_regression_tfidif", data=tp, hue = tp.index, s = 200);

# %%
tp.columns
# Out:
# Index(['extra_trees_cvec', 'extra_trees_tfidif', 'extra_trees_wit_grid_cvec',
#        'extra_trees_wit_grid_tfidif', 'k_nearest_neighbor_cvec',
#        'k_nearest_neighbor_tfidif', 'k_nearest_neighbor_with_grid_cvec',
#        'k_nearest_neighbor_with_grid_tfidif', 'linear_regression_cvec',
#        'linear_regression_tfidif', 'linear_regression_with_grid_cvec',
#        'linear_regression_with_grid_tfidif', 'random_forrest_cvec',
#        'random_forrest_tfidif', 'random_forrest_with_grid_cvec',
#        'random_forrest_with_grid_tfidif', 'voting_class_boost_cvec',
#        'voting_class_boost_tfidif'],
#       dtype='object', name='Model')

# %%
plt.figure(figsize = (10,10))
sns.set()
sns.scatterplot(x="linear_regression_with_grid_cvec", y="linear_regression_with_grid_tfidif", data=tp, hue = tp.index, s = 200);

# %%
plt.figure(figsize = (10,10))
sns.set()
sns.scatterplot(x="random_forrest_cvec", y="random_forrest_tfidif", data=tp, hue = tp.index, s = 200);

# %%
plt.figure(figsize = (10,10))

sns.set()
sns.scatterplot(x="random_forrest_with_grid_cvec", y="random_forrest_with_grid_tfidif", data=tp, hue = tp.index, s = 200);

# %%
tp.columns
# Out:
# Index(['extra_trees_cvec', 'extra_trees_tfidif', 'extra_trees_wit_grid_cvec',
#        'extra_trees_wit_grid_tfidif', 'k_nearest_neighbor_cvec',
#        'k_nearest_neighbor_tfidif', 'k_nearest_neighbor_with_grid_cvec',
#        'k_nearest_neighbor_with_grid_tfidif', 'linear_regression_cvec',
#        'linear_regression_tfidif', 'linear_regression_with_grid_cvec',
#        'linear_regression_with_grid_tfidif', 'random_forrest_cvec',
#        'random_forrest_tfidif', 'random_forrest_with_grid_cvec',
#        'random_forrest_with_grid_tfidif', 'voting_class_boost_cvec',
#        'voting_class_boost_tfidif'],
#       dtype='object', name='Model')

# %%
plt.figure(figsize = (10,10))

sns.set()
sns.scatterplot(x="voting_class_boost_cvec", y="voting_class_boost_tfidif", data=tp, hue = tp.index, s = 200);

# %%
mis_cvec = mis[mis.Model.str.contains('_cvec')].reset_index(drop = True)
#combined['Misclassification Rate']

# %%
mis_cvec['Model'] = mis_cvec.Model.str.rstrip('_cvec')

mis_cvec.rename( columns = {'Misclassification Rate' : 'misclassification_rate_cvec'}, inplace = True)

# %%
mis_cvec
# Out:
#                           Model  misclassification_rate_cvec
# 0                   extra_trees                     0.049938
# 1          extra_trees_wit_grid                     0.049938
# 2            k_nearest_neighbor                     0.696629
# 3  k_nearest_neighbor_with_grid                     0.696629
# 4             linear_regression                     0.164794
# 5   linear_regression_with_grid                     0.058677
# 6                random_forrest                     0.052434
# 7      random_forrest_with_grid                     0.073658
# 8            voting_class_boost                     0.077403

# %%
mis_tfidif = mis[mis.Model.str.contains('_tfidif')].reset_index(drop = True)

# %%
mis_tfidif['Model'] = mis_tfidif.Model.str.rstrip('_tfidif')

mis_tfidif.rename( columns = {'Misclassification Rate' : 'misclassification_rate_tfidif'}, inplace = True)

# %%
mis_tfidif
# Out:
#                         Model  misclassification_rate_tfidif
# 0                 extra_trees                       0.036205
# 1          extra_trees_wit_gr                       0.036205
# 2          k_nearest_neighbor                       0.722846
# 3  k_nearest_neighbor_with_gr                       0.722846
# 4           linear_regression                       0.081149
# 5   linear_regression_with_gr                       0.066167
# 6               random_forres                       0.049938
# 7      random_forrest_with_gr                       0.057428
# 8           voting_class_boos                       0.053683

# %%
mis_rates = pd.concat([mis_cvec, mis_tfidif.iloc[:,1]], axis = 1 ).set_index('Model')

# %%
plt.figure(figsize = (10,10))

sns.set()
sns.scatterplot(x="misclassification_rate_cvec", y="misclassification_rate_tfidif", data=mis_rates, hue = precision_viz.index, s = 200)
plt.title('NLP Subreddit Binary Classifier \n Count Vectorizor vs TF-IDF Vectorizor Model Misclassification Rate', size = 23, pad = 10)
plt.ylabel('TF-IDF Vectorizor Model Misclassification Rate', size = 16, labelpad = 10)
plt.xlabel('Count Vectorizor Model Misclassification Rate', size = 16, labelpad = 10);

plt.savefig('./visualization_images/classifier_misclassification.png')

# %%
tp
# Out:
# Model        extra_trees_cvec  extra_trees_tfidif  extra_trees_wit_grid_cvec  \
# Accuracy             0.950062            0.963795                   0.950062
# Sensitivity          0.987611            0.987847                   0.987611
# Specificity          0.860169            0.902222                   0.860169
# Precision            0.944162            0.962775                   0.944162
#
# Model        extra_trees_wit_grid_tfidif  k_nearest_neighbor_cvec  \
# Accuracy                        0.963795                 0.303371
# Sensitivity                     0.987847                 0.971429
# Specificity                     0.902222                 0.272846
# Precision                       0.962775                 0.057530
#
# Model        k_nearest_neighbor_tfidif  k_nearest_neighbor_with_grid_cvec  \
# Accuracy                      0.277154                           0.303371
# Sensitivity                   1.000000                           0.971429
# ...

# %%
accuracy = pd.DataFrame(tp.iloc[0,:])

# %%
accuracy_cvec = accuracy[accuracy.index.str.contains('cvec')]
accuracy_cvec.index = accuracy_cvec.index.str.rstrip('cvec')

accuracy_cvec.rename( columns = {'Accuracy' : 'accuracy_cvec'}, inplace = True)
# Out:
# /Users/joseluisnavarrojr/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
accuracy_tfidif = accuracy[accuracy.index.str.contains('_tfidif')]
accuracy_tfidif.index = accuracy_tfidif.index.str.rstrip('tfidif')

accuracy_tfidif.rename( columns = {'Accuracy' : 'accuracy_tfidif'}, inplace = True)
# Out:
# /Users/joseluisnavarrojr/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
accuracy_viz = pd.concat([accuracy_tfidif,accuracy_cvec.iloc[:,0]], axis = 1)

# %%
accuracy_viz
# Out:
#                                accuracy_tfidif  accuracy_cvec
# Model
# extra_trees_                          0.963795       0.950062
# extra_trees_wit_grid_                 0.963795       0.950062
# k_nearest_neighbor_                   0.277154       0.303371
# k_nearest_neighbor_with_grid_         0.277154       0.303371
# linear_regression_                    0.918851       0.835206
# linear_regression_with_grid_          0.933833       0.941323
# random_forrest_                       0.950062       0.947566
# random_forrest_with_grid_             0.942572       0.926342
# voting_class_boost_                   0.946317       0.922597

# %%
plt.figure(figsize = (10,10))

sns.set()
sns.scatterplot(x="accuracy_cvec", y="accuracy_tfidif", data=accuracy_viz, hue = precision_viz.index, s = 200)
plt.title('NLP Subreddit Binary Classifier \n Count Vectorizor vs TF-IDF Vectorizor Model Accuracy', size = 23, pad = 10)
plt.ylabel('TF-IDF Vectorizor Model Accuracy', size = 16, labelpad = 10)
plt.xlabel('Count Vectorizor Model Accuracy', size = 16, labelpad = 10);

plt.savefig('./visualization_images/classifier_accuracy.png')

# %%
sensitivity = pd.DataFrame(tp.iloc[1,:])

# %%
sensitivity_cvec = sensitivity[sensitivity.index.str.contains('_cvec')]
sensitivity_cvec.index = sensitivity_cvec.index.str.rstrip('cvec')

sensitivity_cvec.rename( columns = {'Sensitivity' : 'sensitivity_cvec'}, inplace = True)
# Out:
# /Users/joseluisnavarrojr/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
sensitivity_tfidif = sensitivity[sensitivity.index.str.contains('_tfidif')]
sensitivity_tfidif.index = sensitivity_tfidif.index.str.rstrip('tfidif')

sensitivity_tfidif.rename( columns = {'Sensitivity' : 'sensitivity_tfidif'}, inplace = True)
# Out:
# /Users/joseluisnavarrojr/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
sensitivity_viz = pd.concat([sensitivity_tfidif,sensitivity_cvec.iloc[:,0]], axis = 1)

# %%
sensitivity_viz
# Out:
#                                sensitivity_tfidif  sensitivity_cvec
# Model
# extra_trees_                             0.987847          0.987611
# extra_trees_wit_grid_                    0.987847          0.987611
# k_nearest_neighbor_                      1.000000          0.971429
# k_nearest_neighbor_with_grid_            1.000000          0.971429
# linear_regression_                       0.979927          0.993548
# linear_regression_with_grid_             0.954392          0.990975
# random_forrest_                          0.984183          0.987567
# random_forrest_with_grid_                0.980600          0.927653
# voting_class_boost_                      0.970790          0.941569

# %%
plt.figure(figsize = (10,10))

sns.set()
sns.scatterplot(x="sensitivity_cvec", y="sensitivity_tfidif", data=sensitivity_viz, hue = precision_viz.index, s = 200)
plt.title('NLP Subreddit Binary Classifier \n Count Vectorizor vs TF-IDF Vectorizor Model Sensitivity', size = 23, pad = 10)
plt.ylabel('TF-IDF Vectorizor Model Sensitivity', size = 16, labelpad = 10)
plt.xlabel('Count Vectorizor Model Sensitivity', size = 16, labelpad = 10);

plt.savefig('./visualization_images/classifier_sensitivity.png')

# %%
specificity = pd.DataFrame(tp.iloc[2,:])

# %%
specificity_cvec = specificity[specificity.index.str.contains('_cvec')]
specificity_cvec.index = specificity_cvec.index.str.rstrip('cvec')

specificity_cvec.rename( columns = {'Specificity' : 'specificity_cvec'}, inplace = True)
# Out:
# /Users/joseluisnavarrojr/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
specificity_tfidif = specificity[specificity.index.str.contains('_tfidif')]
specificity_tfidif.index = specificity_tfidif.index.str.rstrip('tfidif')

specificity_tfidif.rename( columns = {'Specificity' : 'specificity_tfidif'}, inplace = True)
# Out:
# /Users/joseluisnavarrojr/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
specificity_viz = pd.concat([specificity_tfidif,specificity_cvec.iloc[:,0]], axis = 1)

# %%
specificity_viz
# Out:
#                                specificity_tfidif  specificity_cvec
# Model
# extra_trees_                             0.902222          0.860169
# extra_trees_wit_grid_                    0.902222          0.860169
# k_nearest_neighbor_                      0.266160          0.272846
# k_nearest_neighbor_with_grid_            0.266160          0.272846
# linear_regression_                       0.786561          0.616071
# linear_regression_with_grid_             0.875598          0.829960
# random_forrest_                          0.866379          0.852941
# random_forrest_with_grid_                0.850427          0.921788
# voting_class_boost_                      0.881279          0.866337

# %%
plt.figure(figsize = (10,10))

sns.set()
sns.scatterplot(x="specificity_cvec", y="specificity_tfidif", data=specificity_viz, hue = precision_viz.index, s = 200)
plt.title('NLP Subreddit Binary Classifier \n Count Vectorizor vs TF-IDF Vectorizor Model Specificity', size = 23, pad = 10)
plt.ylabel('TF-IDF Vectorizor Model Specificity', size = 16, labelpad = 10)
plt.xlabel('Count Vectorizor Model Specificity', size = 16, labelpad = 10);

plt.savefig('./visualization_images/classifier_specificity.png')

# %%
precision = pd.DataFrame(tp.iloc[3,:])

# %%
precision_cvec = precision[precision.index.str.contains('_cvec')]
precision_cvec.index = precision_cvec.index.str.rstrip('cvec')

precision_cvec.rename( columns = {'Precision' : 'precision_cvec'}, inplace = True)

# %%
precision_tfidif = precision[precision.index.str.contains('_tfidif')]
precision_tfidif.index = precision_tfidif.index.str.rstrip('tfidif')

precision_tfidif.rename( columns = {'Precision' : 'precision_tfidif'}, inplace = True)
# Out:
# /Users/joseluisnavarrojr/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
precision_viz = pd.concat([precision_tfidif,precision_cvec.iloc[:,0]], axis = 1)

# %%
precision_viz
# Out:
#                                precision_tfidif  precision_cvec
# Model
# extra_trees_                           0.962775        0.944162
# extra_trees_wit_grid_                  0.962775        0.944162
# k_nearest_neighbor_                    0.020305        0.057530
# k_nearest_neighbor_with_grid_          0.020305        0.057530
# linear_regression_                     0.908629        0.781726
# linear_regression_with_grid_           0.956007        0.928934
# random_forrest_                        0.947547        0.940778
# random_forrest_with_grid_              0.940778        0.976311
# voting_class_boost_                    0.956007        0.954315

# %%
model_names = ['Extra Trees', 'Extra Trees Using GridSearchCV', 'K Nearest Neighbors', 
               'K Nearest Neighbors Using GridSearchCV', 'Linear Regression', 'Linear Regression Using GridSearchCV',
              'Random Forrest', 'Random Forrest Using GridSearchCV', 'VotingClassifier with Boosts']
precision_viz.index = model_names
precision_viz.index.name = 'Machine Learning Model'
precision_viz
# Out:
#                                         precision_tfidif  precision_cvec
# Machine Learning Model
# Extra Trees                                     0.962775        0.944162
# Extra Trees Using GridSearchCV                  0.962775        0.944162
# K Nearest Neighbors                             0.020305        0.057530
# K Nearest Neighbors Using GridSearchCV          0.020305        0.057530
# Linear Regression                               0.908629        0.781726
# Linear Regression Using GridSearchCV            0.956007        0.928934
# Random Forrest                                  0.947547        0.940778
# Random Forrest Using GridSearchCV               0.940778        0.976311
# VotingClassifier with Boosts                    0.956007        0.954315

# %%
plt.figure(figsize = (10,10))


sns.set()
sns.scatterplot(x="precision_cvec", y="precision_tfidif", data=precision_viz, hue = precision_viz.index, s = 200)
plt.title('NLP Subreddit Binary Classifier \n Count Vectorizor vs TF-IDF Vectorizor Model Precision', size = 23, pad = 10)
plt.ylabel('TF-IDF Vectorizor Model Precision', size = 16, labelpad = 10)
plt.xlabel('Count Vectorizor Model Precision', size = 16, labelpad = 10);

plt.savefig('./visualization_images/classifier_precision.png')
